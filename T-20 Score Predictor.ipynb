# %% [markdown]
# First, we import the libraries we need.

# %%
import pandas as pd
import os
import numpy as np
from scipy import stats
from sklearn import linear_model

# %% [markdown]
# We iterate through every match in our folder, represented by a csv file, and create a dataframe containing the relevant data for each match. We call this function process_csv_all().

# %%
def clean_ball_notation(match):
    roots = [0.0 + i for i in range(20)]
    ball_lst = []
    for root in roots:
        ball_lst.append(root + 0.1)
        ball_lst.append(root + 0.2)
        ball_lst.append(root + 0.3)
        ball_lst.append(root + 0.4)
        ball_lst.append(root + 0.5)
        ball_lst.append(root + 0.6)
        
    
        
    
    new_ball_notation = []
    num_of_match_rows = 0
    ball_notation = 0.1
    ball_counter = 0
    for index, row in match.iterrows():
        num_of_match_rows = index
        
    for index, row in match.iterrows():
                    
        current_innings = row["innings"]
        if (ball_counter > 1):          
            previous_innings = match["innings"][index-1]
            if (current_innings != previous_innings):
                ball_counter = 0
                
        ball_notation = ball_lst[ball_counter]
        
        if index == num_of_match_rows:
            new_ball_notation.append(str(ball_notation))
            break
            
            
        ball_score = row["runs_scored"] + row["extras_scored"]
        
        condition_odd_score = (ball_score % 2 == 1)
        
        current_striker = row["batsman_on_strike"]
        next_striker = match["batsman_on_strike"][index+1]
        condition_same_striker = (current_striker == next_striker)
        
        current_nonstriker = row["batsman_off_strike"]
        next_nonstriker = match["batsman_off_strike"][index+1]
        condition_same_nonstriker = (current_nonstriker == next_nonstriker) 
        
        condition_strike_correct = (condition_same_striker or condition_same_nonstriker)
        
        condition_wicket = False
        if not pd.isna(row["type_of_dismissal"]):
            condition_wicket = True
            new_ball_notation.append(str(ball_notation))
            ball_counter += 1
            continue
        
        current_bowler = row["bowler"]
        next_bowler = next_striker = match["bowler"][index+1]
        condition_new_over = (current_bowler != next_bowler)
        
        if (condition_odd_score == condition_strike_correct):
            if not (condition_new_over):
                new_ball_notation.append(str(ball_notation))
            else:
                new_ball_notation.append(str(ball_notation))
                ball_counter += 1
            
        else:
            if not (condition_new_over):
                new_ball_notation.append(str(ball_notation))
                ball_counter += 1
            else:
                new_ball_notation.append(str(ball_notation))
            
    match["ball_notation"] = new_ball_notation
    return match

# %%
def process_csv_all():
    not_able_to_clean = 0
    files = os.listdir(r"/Users/suchirjoshi/Desktop/Cricket Analytics/T20 + Major Leagues folder/")
    folder = files[0:len(files)-1]
    csvs = []
    for file in folder:
        if file.endswith('.csv'):
            cleaned_file = pd.read_csv((r"/Users/suchirjoshi/Desktop/Cricket Analytics/T20 + Major Leagues folder/" + 
                        file), names=(["type", "innings", "ball_notation", "team_batting", 
                                                      "batsman_on_strike", "batsman_off_strike", "bowler",
                                                       "runs_scored", "extras_scored", "type_of_dismissal", 
                                                       "person_of_dismissal"]), engine='python')
            
            try:
                cleaned_file = clean_ball_notation(cleaned_file)
            except IndexError:
                not_able_to_clean += 1
        
        
            csvs.append(cleaned_file.dropna(thresh=4))
        
    return csvs

# %% [markdown]
# Now, we call process_csv_all() to generate this list of dataframes.

# %%
list_of_matches = process_csv_all()

# %% [markdown]
# This adds some features to a given match table.

# %%
def convert(notation):
    num = float(notation)
    overs = int(num)
    balls = (num * 10) % 10
    return (overs * 6) + balls

# %%
def add_cols(match):
    try:
    
        runs = []
        runs_so_far = []
        wickets_so_far = []

        balls_done = []
        first_innings = match.loc[match["innings"] == "1"]
        total_balls_first = len(first_innings)
        first_index = 1

        count = 0
        run_count = 0
        wickets = 0

        total_score = []
        for i in np.arange(len(first_innings)):
            if pd.isna(first_innings["type_of_dismissal"].iloc[i]):
                count += first_innings["runs_scored"].iloc[i]
                count += first_innings["extras_scored"].iloc[i]
                runs.append(count)

                run_count += first_innings["runs_scored"].iloc[i]
                run_count += first_innings["extras_scored"].iloc[i]
                runs_so_far.append(run_count)
                wickets_so_far.append(wickets)
            else:
                count = 0
                run_count += first_innings["runs_scored"].iloc[i]
                run_count += first_innings["extras_scored"].iloc[i]
                runs_so_far.append(run_count)
                runs.append(count)
                wickets += 1
                wickets_so_far.append(wickets)

            balls_done.append(convert(first_innings["ball_notation"].iloc[i]))
            first_index += 1

        for i in np.arange(len(first_innings)):
            total_score.append(runs_so_far[len(runs_so_far)-1])

        second_innings = match.loc[match["innings"] == "2"]
        count = 0
        run_count = 0
        wickets = 0
        total_balls_second = len(second_innings)
        second_index = 1

        for i in np.arange(len(second_innings)):
            if pd.isna(second_innings["type_of_dismissal"].iloc[i]):
                count += second_innings["runs_scored"].iloc[i]
                count += second_innings["extras_scored"].iloc[i]
                runs.append(count)

                run_count += second_innings["runs_scored"].iloc[i]
                run_count += second_innings["extras_scored"].iloc[i]
                runs_so_far.append(run_count)
                wickets_so_far.append(wickets)
            else:
                count = 0
                run_count += second_innings["runs_scored"].iloc[i]
                run_count += second_innings["extras_scored"].iloc[i]
                runs_so_far.append(run_count)
                runs.append(count)
                wickets += 1
                wickets_so_far.append(wickets)

            balls_done.append(convert(second_innings["ball_notation"].iloc[i]))
            second_index += 1

        for i in np.arange(len(second_innings)):
            total_score.append(runs_so_far[len(runs_so_far)-1])

        if (len(runs) != len(match)):
            return None

        if (len(runs_so_far) != len(match)):
            return None

        if (len(balls_done) != len(match)):
            return None

        match["Runs since last wicket"] = runs
        match["Total runs"] = runs_so_far
        match["Innings balls done"] = balls_done
        match["Total Inings Score"] = total_score
        match["Total Wickets"] = wickets_so_far
        return match
    
    except:
        return None

# %%
sixth_match = list_of_matches[6]
add_cols(sixth_match)
# Out:
#      type innings ball_notation team_batting batsman_on_strike  \
# 21   ball       1           0.1        India         G Gambhir
# 22   ball       1           0.2        India         G Gambhir
# 23   ball       1           0.3        India         G Gambhir
# 24   ball       1           0.4        India         G Gambhir
# 25   ball       1           0.5        India         RG Sharma
# 26   ball       1           0.6        India         G Gambhir
# 27   ball       1           1.1        India         RG Sharma
# 28   ball       1           1.2        India         RG Sharma
# 29   ball       1           1.3        India         G Gambhir
# 30   ball       1           1.4        India         G Gambhir
# 31   ball       1           1.5        India         G Gambhir
# 32   ball       1           1.6        India          SK Raina
# 98   ball       1          12.4        India      Yuvraj Singh
# 99   ball       1          12.5        India         YK Pathan
# 100  ball       1          12.6        India         YK Pathan
# 101  ball       1          13.1        India         YK Pathan
# 102  ball       1          13.2        India         YK Pathan
# 103  ball       1          13.3        India      Yuvraj Singh
# 104  ball       1          13.4        India      Yuvraj Singh
# 105  ball       1          13.5        India      Yuvraj Singh
# 106  ball       1          13.6        India      Yuvraj Singh
# 107  ball       1          13.7        India      Yuvraj Singh
# 108  ball       1          14.1        India         YK Pathan
# 109  ball       1          14.2        India         YK Pathan
# 110  ball       1          14.3        India      Yuvraj Singh
# 111  ball       1          14.4        India      Yuvraj Singh
# 112  ball       1          14.5        India         YK Pathan
# 113  ball       1          14.6        India         YK Pathan
# 114  ball       1          15.1        India      Yuvraj Singh
# 115  ball       1          15.2        India         YK Pathan
# 116  ball       1          15.3        India         YK Pathan
# 117  ball       1          15.4        India         YK Pathan
# 118  ball       1          15.5        India      Yuvraj Singh
# 119  ball       1          15.6        India      Yuvraj Singh
# 120  ball       1          16.1        India         YK Pathan
# 121  ball       1          16.2        India      Yuvraj Singh
# 122  ball       1          16.3        India      Yuvraj Singh
# 123  ball       1          16.4        India      Yuvraj Singh
# 124  ball       1          16.5        India      Yuvraj Singh
# 125  ball       1          16.6        India      Yuvraj Singh
# 126  ball       1          17.1        India         YK Pathan
# 127  ball       1          17.2        India         YK Pathan
# 128  ball       1          17.3        India         YK Pathan
# 129  ball       1          17.4        India         YK Pathan
# 130  ball       1          17.5        India      Yuvraj Singh
# 131  ball       1          17.6        India         YK Pathan
# 132  ball       1          17.7        India         IK Pathan
# 133  ball       1          18.1        India         YK Pathan
# 134  ball       1          18.2        India         YK Pathan
# 135  ball       1          18.3        India         YK Pathan
# 136  ball       1          18.4        India         YK Pathan
# 137  ball       1          18.5        India         YK Pathan
# 138  ball       1          18.6        India         IK Pathan
# 139  ball       1          19.1        India         YK Pathan
# 140  ball       1          19.2        India   Harbhajan Singh
# 141  ball       1          19.3        India         IK Pathan
# 142  ball       1          19.4        India   Harbhajan Singh
# 143  ball       1          19.5        India   Harbhajan Singh
# 144  ball       1          19.6        India   Harbhajan Singh
# 145  ball       2           0.1  West Indies          CH Gayle
# 146  ball       2           0.2  West Indies          CH Gayle
# 147  ball       2           0.3  West Indies          CH Gayle
# 148  ball       2           0.4  West Indies          CH Gayle
# 149  ball       2           0.5  West Indies          CH Gayle
# 150  ball       2           0.6  West Indies          CH Gayle
# 151  ball       2           1.1  West Indies      ADS Fletcher
# 152  ball       2           1.2  West Indies      ADS Fletcher
# 153  ball       2           1.3  West Indies      ADS Fletcher
# 154  ball       2           1.4  West Indies       LMP Simmons
# 155  ball       2           1.5  West Indies          CH Gayle
# 156  ball       2           1.6  West Indies          CH Gayle
# 157  ball       2           1.7  West Indies       LMP Simmons
# 158  ball       2           2.1  West Indies       LMP Simmons
# 159  ball       2           2.2  West Indies          CH Gayle
# 160  ball       2           2.3  West Indies          CH Gayle
# 161  ball       2           2.4  West Indies       LMP Simmons
# 162  ball       2           2.5  West Indies       LMP Simmons
# 163  ball       2           2.6  West Indies       LMP Simmons
# 164  ball       2           3.1  West Indies          CH Gayle
# 165  ball       2           3.2  West Indies          CH Gayle
# 166  ball       2           3.3  West Indies          CH Gayle
# 167  ball       2           3.4  West Indies       LMP Simmons
# 168  ball       2           3.5  West Indies       LMP Simmons
# 169  ball       2           3.6  West Indies          CH Gayle
# 170  ball       2           4.1  West Indies       LMP Simmons
# 171  ball       2           4.2  West Indies          CH Gayle
# 172  ball       2           4.3  West Indies          CH Gayle
# 173  ball       2           4.4  West Indies          CH Gayle
# 174  ball       2           4.5  West Indies       LMP Simmons
# 175  ball       2           4.6  West Indies       LMP Simmons
# 176  ball       2           5.1  West Indies          CH Gayle
# 177  ball       2           5.2  West Indies          CH Gayle
# 178  ball       2           5.3  West Indies          CH Gayle
# 179  ball       2           5.4  West Indies          CH Gayle
# 180  ball       2           5.5  West Indies          CH Gayle
# 181  ball       2           5.6  West Indies          CH Gayle
# 182  ball       2           6.1  West Indies       LMP Simmons
# 183  ball       2           6.2  West Indies       LMP Simmons
# 184  ball       2           6.3  West Indies          CH Gayle
# 185  ball       2           6.4  West Indies          CH Gayle
# 186  ball       2           6.5  West Indies          CH Gayle
# 187  ball       2           6.6  West Indies       LMP Simmons
# 188  ball       2           7.1  West Indies       LMP Simmons
# 189  ball       2           7.2  West Indies          CH Gayle
# 190  ball       2           7.3  West Indies       LMP Simmons
# 191  ball       2           7.4  West Indies          CH Gayle
# 192  ball       2           7.5  West Indies          DJ Bravo
# 193  ball       2           7.6  West Indies       LMP Simmons
# 194  ball       2           8.1  West Indies       LMP Simmons
# 195  ball       2           8.2  West Indies          DJ Bravo
# 196  ball       2           8.3  West Indies          DJ Bravo
# 197  ball       2           8.4  West Indies          DJ Bravo
# 198  ball       2           8.5  West Indies       LMP Simmons
# 199  ball       2           8.6  West Indies          DJ Bravo
# 200  ball       2           9.1  West Indies       LMP Simmons
# 201  ball       2           9.2  West Indies          DJ Bravo
# 202  ball       2           9.3  West Indies          DJ Bravo
# 203  ball       2           9.4  West Indies          DJ Bravo
# 204  ball       2           9.5  West Indies          DJ Bravo
# 205  ball       2           9.6  West Indies          DJ Bravo
# 206  ball       2          10.1  West Indies          DJ Bravo
# 207  ball       2          10.2  West Indies       LMP Simmons
# 208  ball       2          10.3  West Indies          DJ Bravo
# 209  ball       2          10.4  West Indies       LMP Simmons
# 210  ball       2          10.5  West Indies       LMP Simmons
# 211  ball       2          10.6  West Indies          DJ Bravo
# 212  ball       2          11.1  West Indies          DJ Bravo
# 213  ball       2          11.2  West Indies          DJ Bravo
# 214  ball       2          11.3  West Indies          DJ Bravo
# 215  ball       2          11.4  West Indies       LMP Simmons
# 216  ball       2          11.5  West Indies       LMP Simmons
# 217  ball       2          11.6  West Indies          DJ Bravo
# 218  ball       2          12.1  West Indies       LMP Simmons
# 219  ball       2          12.2  West Indies       LMP Simmons
# 220  ball       2          12.3  West Indies       LMP Simmons
# 221  ball       2          12.4  West Indies       LMP Simmons
# 222  ball       2          12.5  West Indies       LMP Simmons
# 223  ball       2          12.6  West Indies       LMP Simmons
# 224  ball       2          12.7  West Indies       LMP Simmons
# 225  ball       2          13.1  West Indies       LMP Simmons
# 226  ball       2          13.2  West Indies          DJ Bravo
# 227  ball       2          13.3  West Indies       LMP Simmons
# 228  ball       2          13.4  West Indies       LMP Simmons
# 229  ball       2          13.5  West Indies          DJ Bravo
# 230  ball       2          13.6  West Indies       LMP Simmons
# 231  ball       2          13.7  West Indies       LMP Simmons
# 232  ball       2          14.1  West Indies       LMP Simmons
# 233  ball       2          14.2  West Indies          DJ Bravo
# 234  ball       2          14.3  West Indies       LMP Simmons
# 235  ball       2          14.4  West Indies          DJ Bravo
# 236  ball       2          14.5  West Indies          DJ Bravo
# 237  ball       2          14.6  West Indies          DJ Bravo
# 238  ball       2          15.1  West Indies          DJ Bravo
# 239  ball       2          15.2  West Indies     S Chanderpaul
# 240  ball       2          15.3  West Indies          DJ Bravo
# 241  ball       2          15.4  West Indies          DJ Bravo
# 242  ball       2          15.5  West Indies     S Chanderpaul
# 243  ball       2          15.6  West Indies     S Chanderpaul
# 244  ball       2          16.1  West Indies     S Chanderpaul
# 245  ball       2          16.2  West Indies          DJ Bravo
# 246  ball       2          16.3  West Indies          DJ Bravo
# 247  ball       2          16.4  West Indies          DJ Bravo
# 248  ball       2          16.5  West Indies          DJ Bravo
# 249  ball       2          16.6  West Indies     S Chanderpaul
# 250  ball       2          17.1  West Indies          DJ Bravo
# 251  ball       2          17.2  West Indies          DJ Bravo
# 252  ball       2          17.3  West Indies          DJ Bravo
# 253  ball       2          17.4  West Indies          DJ Bravo
# 254  ball       2          17.5  West Indies     S Chanderpaul
# 255  ball       2          17.6  West Indies     S Chanderpaul
# 256  ball       2          18.1  West Indies          DJ Bravo
# 257  ball       2          18.2  West Indies     S Chanderpaul
# 258  ball       2          18.3  West Indies     S Chanderpaul
# 259  ball       2          18.4  West Indies          DJ Bravo
#
#     batsman_off_strike           bowler  runs_scored  extras_scored  \
# 21           RG Sharma        JE Taylor          0.0            0.0
# 22           RG Sharma        JE Taylor          4.0            0.0
# 23           RG Sharma        JE Taylor          0.0            0.0
# 24           RG Sharma        JE Taylor          1.0            0.0
# 25           G Gambhir        JE Taylor          1.0            0.0
# 26           RG Sharma        JE Taylor          2.0            0.0
# 27           G Gambhir       FH Edwards          4.0            0.0
# 28           G Gambhir       FH Edwards          0.0            0.0
# 29            SK Raina       FH Edwards          0.0            0.0
# 30            SK Raina       FH Edwards          0.0            0.0
# 31            SK Raina       FH Edwards          1.0            0.0
# 32           G Gambhir       FH Edwards          1.0            0.0
# 33           G Gambhir        JE Taylor          1.0            0.0
# 34            SK Raina        JE Taylor          0.0            1.0
# 35            SK Raina        JE Taylor          0.0            1.0
# 36           G Gambhir        JE Taylor          3.0            0.0
# 37            SK Raina        JE Taylor          4.0            0.0
# 237       109.0                90.0               156.0              3
# 238       110.0                91.0               156.0              3
# 239       111.0                92.0               156.0              3
# 240       113.0                93.0               156.0              3
# 241       114.0                94.0               156.0              3
# 242       114.0                95.0               156.0              3
# 243       115.0                96.0               156.0              3
# 244       116.0                97.0               156.0              3
# 245       118.0                98.0               156.0              3
# 246       124.0                99.0               156.0              3
# 247       126.0               100.0               156.0              3
# 248       127.0               101.0               156.0              3
# 249       131.0               102.0               156.0              3
# 250       131.0               103.0               156.0              3
# 251       135.0               104.0               156.0              3
# 252       137.0               105.0               156.0              3
# 253       138.0               106.0               156.0              3
# 254       142.0               107.0               156.0              3
# 255       146.0               108.0               156.0              3
# 256       147.0               109.0               156.0              3
# 257       149.0               110.0               156.0              3
# 258       150.0               111.0               156.0              3
# 259       156.0               112.0               156.0              3

# %%
list_of_matches_with_features = [add_cols(match) for match in list_of_matches if add_cols(match) is not None]

# %%
len(list_of_matches_with_features)
# Out:
# 1504

# %%
first_innings_with_features = [match.loc[match["innings"] == "1"] for match in list_of_matches_with_features]

# %%
len(first_innings_with_features)
# Out:
# 1504

# %%
def convert_to_standard_units(column):
    
    mean = np.mean(column)
    std_dev = np.std(column)
    
    return [(element - mean) / std_dev for element in column]
    #return column

# %%
from sklearn.model_selection import train_test_split

no_convert = 0
reg = linear_model.LinearRegression()
total_runs = []
innings_balls_done = []
total_wickets = []
total_innings_score = []
runs_since_last_wicket = []
team_batting = []
for match in first_innings_with_features:
    
    try:
        total_runs.extend(convert_to_standard_units(match["Total runs"]))
        innings_balls_done.extend(convert_to_standard_units(match["Innings balls done"]))
        total_wickets.extend(convert_to_standard_units(match["Total Wickets"]))
        total_innings_score.extend(match["Total Inings Score"])
        runs_since_last_wicket.extend(convert_to_standard_units(match["Runs since last wicket"]))
        #team_batting.extend(match["team_batting"])
    except:
        no_convert += 1
    
x = []
for i in np.arange(len(total_wickets)):
    x.append([total_runs[i], innings_balls_done[i], total_wickets[i], runs_since_last_wicket[i]])

y = total_innings_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
reg.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_prediction = reg.predict(x_test)
r2_score(y_test, y_prediction)
# Out:
# -0.00014637996504718309

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
rf.score(x_test, y_test)
# Out:
# 0.72210263881644976

# %%
rf.predict([[0.1, 0, 0, 0]])
# Out:
# array([ 170.8])

# %%
from sklearn.neighbors import KNeighborsRegressor
neighbor = KNeighborsRegressor(n_neighbors=3, weights="distance")
neighbor.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#           weights='distance')

# %%
pred = neighbor.predict(x_test)
r2_score(y_test, pred)
# Out:
# 0.25569132291446217

# %%
neighbor.predict([[1, 0, 0, 0]])
# Out:
# array([ 130.81631761])
